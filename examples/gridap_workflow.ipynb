# %%
import Gridap
using Gridap.Geometry
using Gridap.FESpaces
using Gridap.ReferenceFEs
using Gridap.Arrays
using Gridap.Fields
using Gridap.CellData
using FillArrays

# %%
domain = (0.0, 1.0, 0.0, 1.0)
partition = (2,3)
model = CartesianDiscreteModel(domain,partition)
pol = Polytope(Fill(HEX_AXIS,2)...)
reffe = LagrangianRefFE(Float64,pol,2)

f(x) = 1.0
g(x) = 0.0

Vₕ = TestFESpace(model,reffe;conformity=:H1,dirichlet_tags=["boundary"])
Uₕ = TrialFESpace(Vₕ, g)
Ω = Triangulation(model)
dΩ = Measure(Ω,2)

# Weak Form
a(u,v) = ∫( ∇(v)⋅∇(u) )*dΩ
a(u,v) = ∇(v)⋅∇(u)
b(v) = ∫( v*f )*dΩ 

op = AffineFEOperator(a,b,Uₕ,Vₕ)
# Out:
# This method belongs to an abstract interface definition and cannot be used.
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] macro expansion
#
#    @ ~/.julia/packages/Gridap/nBsSO/src/Helpers/Macros.jl:9 [inlined]
#
#  [3] collect_cell_matrix_and_vector(trial::TrialFESpace{UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.CompressedCellConformity{Fill{Int64, 1, Tuple{Base.OneTo{Int64}}}}}}, test::UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.CompressedCellConformity{Fill{Int64, 1, Tuple{Base.OneTo{Int64}}}}}, mat_contributions::Gridap.CellData.OperationCellField{ReferenceDomain, typeof(dot)}, vec_contributions::DomainContribution, uhd::SingleFieldFEFunction{GenericCellField{ReferenceDomain}})
#
#    @ Gridap.FESpaces ~/.julia/packages/Gridap/nBsSO/src/FESpaces/Assemblers.jl:427
#
#  [4] AffineFEOperator(weakform::Gridap.FESpaces.var"#104#105"{typeof(a), typeof(b)}, trial::TrialFESpace{UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.CompressedCellConformity{Fill{Int64, 1, Tuple{Base.OneTo{Int64}}}}}}, test::UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.CompressedCellConformity{Fill{Int64, 1, Tuple{Base.OneTo{Int64}}}}}, assem::GenericSparseMatrixAssembler)
#
#    @ Gridap.FESpaces ~/.julia/packages/Gridap/nBsSO/src/FESpaces/AffineFEOperators.jl:37
#
#  [5] AffineFEOperator(::Function, ::TrialFESpace{UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.CompressedCellConformity{Fill{Int64, 1, Tuple{Base.OneTo{Int64}}}}}}, ::Vararg{Any})
#
#    @ Gridap.FESpaces ~/.julia/packages/Gridap/nBsSO/src/FESpaces/AffineFEOperators.jl:47
#
#  [6] AffineFEOperator(::typeof(a), ::typeof(b), ::TrialFESpace{UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.CompressedCellConformity{Fill{Int64, 1, Tuple{Base.OneTo{Int64}}}}}}, ::Vararg{Any})
#
#    @ Gridap.FESpaces ~/.julia/packages/Gridap/nBsSO/src/FESpaces/AffineFEOperators.jl:51
#
#  [7] top-level scope
#
#    @ ~/Documents/TU-Delft/WP2/SWE_farfield/TensorProduct/GridapTensorProduct.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:20
